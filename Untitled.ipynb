# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Densech
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
# # Path to the new image directory
# base_dir = "E:\diabetes_disease_classification_FYP\retina_images"

# # Create the data generators
# train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
# val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
# test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# # Create generators to read images from filesystem
# train_generator = train_datagen.flow_from_directory(
#     directory=os.path.join(base_dir, 'train'),
#     target_size=(256, 256),
#     color_mode="rgb",
#     batch_size=32,
#     class_mode="categorical",
#     shuffle=True,
#     seed=42
# )

# val_generator = val_datagen.flow_from_directory(
#     directory=os.path.join(base_dir, 'val'),
#     target_size=(256, 256),
#     color_mode="rgb",
#     batch_size=32,
#     class_mode="categorical",
#     shuffle=True,
#     seed=42
# )

# test_generator = test_datagen.flow_from_directory(
#     directory=os.path.join(base_dir, 'test'),
#     target_size=(256, 256),
#     color_mode="rgb",
#     batch_size=1,
#     class_mode=None,
#     shuffle=False,
#     seed=42
# )

# %%
# base_dir = "E:\\diabetes_disease_classification_FYP\\retina_images"

# # Initialize empty lists to store the images and labels
# images = []
# labels = []

# # Loop through each class' folder
# for class_label in range(5):
#     # Get a list of all the image file names in this folder
#     image_files = os.listdir(os.path.join(base_dir, str(class_label)))
    
#     # Load each image, convert it to an array, and append it to the images list
#     for image_file in image_files:
#         image = load_img(os.path.join(base_dir, str(class_label), image_file), target_size=(256, 256))
#         images.append(img_to_array(image))
        
#         # Append this image's class label to the labels list
#         labels.append(class_label)

# # Convert the lists to numpy arrays
# images = np.array(images)
# labels = np.array(labels)

# %%
# # Split the data into training and testing sets
# train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2, stratify=labels, random_state=42)

# # Further split the training data into training and validation sets
# train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.25, stratify=train_labels, random_state=42)

# %%
print(np.bincount(train_labels))
print(np.bincount(val_labels))
print(np.bincount(test_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(np.bincount(train_labels))
#       2 print(np.bincount(val_labels))
#       3 print(np.bincount(test_labels))
#
# NameError: name 'train_labels' is not defined

# %%
# # Convert labels to one-hot encoding
# train_labels = to_categorical(train_labels, num_classes=5)
# val_labels = to_categorical(val_labels, num_classes=5)

# # Create the data generators
# train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
# val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
# test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# # Create generators to read images from the numpy arrays
# train_generator = train_datagen.flow(train_images, train_labels, batch_size=32)
# val_generator = val_datagen.flow(val_images, val_labels, batch_size=32)
# test_generator = test_datagen.flow(test_images, batch_size=1)

# %%
base_dir = "E:\\diabetes_disease_classification_FYP\\retina_images"

# Initialize empty lists to store the images and labels
images = []
labels = []

# Loop through each class' folder
for class_label in range(5):
    # Get a list of all the image file names in this folder
    image_files = os.listdir(os.path.join(base_dir, str(class_label)))
    
    # Load each image, convert it to an array, and append it to the images list
    for image_file in image_files:
        image = load_img(os.path.join(base_dir, str(class_label), image_file), target_size=(512, 512))
        images.append(img_to_array(image))
        
        # Append this image's class label to the labels list
        labels.append(class_label)

# Convert the lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

# %%
# Split the data into training and testing sets
train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2, stratify=labels, random_state=42)

# Further split the training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(train_images, train_labels, test_size=0.25, stratify=train_labels, random_state=42)

# %%
def plot_images(images, labels):
    # Create a figure to contain the plot.
    fig = plt.figure(figsize=(10, 10))

    # Loop through each class (from 0 to 4)
    for class_label in range(5):
        # Find the index of the first occurrence of this class label in the labels array
        index = np.where(labels == class_label)[0][0]
        
        # Add a subplot for this class
        ax = fig.add_subplot(2, 3, class_label + 1)
        
        # Display the image
        ax.imshow(images[index].astype('uint8'))
        
        # Set the title of the subplot
        ax.set_title("Class: {}".format(class_label))

    # Show the plot
    plt.show()

# Plot the training images
plot_images(train_images, train_labels)

# %%
train_labels = to_categorical(train_labels)
val_labels = to_categorical(val_labels)
test_labels = to_categorical(test_labels)

# Initialize the ImageDataGenerators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Create generators to read images from the numpy arrays
train_generator = train_datagen.flow(train_images, train_labels, batch_size=32)
val_generator = val_datagen.flow(val_images, val_labels, batch_size=32)
test_generator = test_datagen.flow(test_images, batch_size=1)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(256, 256, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=15,
      epochs=50,
      validation_data=val_generator,
      validation_steps=5)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 31s 2s/step - loss: 2.9089 - accuracy: 0.1704 - val_loss: 1.6092 - val_accuracy: 0.2438
# Epoch 2/50
# 15/15 [==============================] - 28s 2s/step - loss: 1.6123 - accuracy: 0.2021 - val_loss: 1.6092 - val_accuracy: 0.2250
# Epoch 3/50
# 15/15 [==============================] - 28s 2s/step - loss: 1.6195 - accuracy: 0.2021 - val_loss: 1.6102 - val_accuracy: 0.1875
# Epoch 4/50
# 15/15 [==============================] - 28s 2s/step - loss: 1.6097 - accuracy: 0.2354 - val_loss: 1.6055 - val_accuracy: 0.2562
# Epoch 5/50
# 15/15 [==============================] - 27s 2s/step - loss: 1.6288 - accuracy: 0.2389 - val_loss: 1.6107 - val_accuracy: 0.2313
# Epoch 6/50
# 15/15 [==============================] - 28s 2s/step - loss: 1.6074 - accuracy: 0.2667 - val_loss: 1.6132 - val_accuracy: 0.1875
# Epoch 7/50
# ...

# %%
# Accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Generate predictions with the model
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

# Convert categorical labels back to class indices
y_true = np.argmax(test_labels, axis=1)

print('Confusion Matrix')
print(confusion_matrix(y_true, y_pred))

print('Classification Report')
target_names = ['0', '1', '2', '3', '4']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 300/300 [==============================] - 7s 22ms/step
# Confusion Matrix
# [[ 8 17 15  5 15]
#  [ 9 16 15  8 12]
#  [13 14 12  8 13]
#  [11 14 14  4 17]
#  [16 16  9 10  9]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.14      0.13      0.14        60
#            1       0.21      0.27      0.23        60
#            2       0.18      0.20      0.19        60
#            3       0.11      0.07      0.08        60
#            4       0.14      0.15      0.14        60
#
#     accuracy                           0.16       300
#    macro avg       0.16      0.16      0.16       300
# weighted avg       0.16      0.16      0.16       300

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.models import Model

# %%
# Load the VGG model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# Freeze the layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers
x = base_model.output
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(5, activation='softmax')(x)

# Create a new model
model = Model(inputs=base_model.input, outputs=predictions)

# %%
# Compile the model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=15,
    epochs=30,
    validation_data=val_generator,
    validation_steps=5)
# Out:
# Epoch 1/30
# 15/15 [==============================] - 185s 12s/step - loss: 4.2974 - accuracy: 0.1947 - val_loss: 1.6788 - val_accuracy: 0.1875
# Epoch 2/30
# 15/15 [==============================] - 182s 12s/step - loss: 1.6175 - accuracy: 0.2058 - val_loss: 1.6100 - val_accuracy: 0.1750
# Epoch 3/30
# 15/15 [==============================] - 181s 12s/step - loss: 1.6104 - accuracy: 0.2035 - val_loss: 1.6102 - val_accuracy: 0.2000
# Epoch 4/30
# 15/15 [==============================] - 182s 12s/step - loss: 1.6274 - accuracy: 0.2013 - val_loss: 3.3612 - val_accuracy: 0.2250
# Epoch 5/30
# 15/15 [==============================] - 182s 12s/step - loss: 1.7414 - accuracy: 0.1726 - val_loss: 1.6098 - val_accuracy: 0.1813
# Epoch 6/30
# 15/15 [==============================] - 189s 13s/step - loss: 1.6097 - accuracy: 0.1937 - val_loss: 1.6099 - val_accuracy: 0.1750
# Epoch 7/30
# ...

# %%
# Accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Create generators to read images from the numpy arrays
train_generator = train_datagen.flow(train_images, train_labels, batch_size=8)
val_generator = val_datagen.flow(val_images, val_labels, batch_size=8)
test_generator = test_datagen.flow(test_images, batch_size=1)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(256, 256, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=15,
      epochs=50,
      validation_data=val_generator,
      validation_steps=5)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 13s 629ms/step - loss: 1.9814 - accuracy: 0.1583 - val_loss: 1.6175 - val_accuracy: 0.2000
# Epoch 2/50
# 15/15 [==============================] - 8s 562ms/step - loss: 1.6605 - accuracy: 0.2167 - val_loss: 1.6107 - val_accuracy: 0.1750
# Epoch 3/50
# 15/15 [==============================] - 8s 555ms/step - loss: 1.6418 - accuracy: 0.1833 - val_loss: 1.6133 - val_accuracy: 0.1250
# Epoch 4/50
# 15/15 [==============================] - 9s 594ms/step - loss: 1.6312 - accuracy: 0.2000 - val_loss: 1.6112 - val_accuracy: 0.1500
# Epoch 5/50
# 15/15 [==============================] - 9s 566ms/step - loss: 1.6352 - accuracy: 0.2000 - val_loss: 1.6104 - val_accuracy: 0.1750
# Epoch 6/50
# 15/15 [==============================] - 9s 586ms/step - loss: 1.6156 - accuracy: 0.1917 - val_loss: 1.7143 - val_accuracy: 0.1750
# Epoch 7/50
# ...

# %%
# Accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# change loss , verbose

# %%
# Create generators to read images from the numpy arrays
train_generator = train_datagen.flow(train_images, train_labels, batch_size=8)
val_generator = val_datagen.flow(val_images, val_labels, batch_size=8)
test_generator = test_datagen.flow(test_images, batch_size=1)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(640, 640, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=15,
      epochs=50,
      validation_data=val_generator,
      validation_steps=5)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 56s 4s/step - loss: 23.2067 - accuracy: 0.1917 - val_loss: 1.6673 - val_accuracy: 0.1500
# Epoch 2/50
# 15/15 [==============================] - 52s 3s/step - loss: 1.6330 - accuracy: 0.2167 - val_loss: 1.6098 - val_accuracy: 0.2000
# Epoch 3/50
# 15/15 [==============================] - 57s 4s/step - loss: 1.6065 - accuracy: 0.2583 - val_loss: 1.6056 - val_accuracy: 0.1000
# Epoch 4/50
# 15/15 [==============================] - 56s 4s/step - loss: 1.7079 - accuracy: 0.3167 - val_loss: 2.1627 - val_accuracy: 0.1750
# Epoch 5/50
# 15/15 [==============================] - 59s 4s/step - loss: 2.0190 - accuracy: 0.1667 - val_loss: 1.6124 - val_accuracy: 0.1000
# Epoch 6/50
# 15/15 [==============================] - 51s 3s/step - loss: 1.6248 - accuracy: 0.1897 - val_loss: 1.6098 - val_accuracy: 0.1750
# Epoch 7/50
# ...

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(640, 640, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=15,
      epochs=50,
      validation_data=val_generator,
      validation_steps=5)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 37s 2s/step - loss: 19.6794 - accuracy: 0.2069 - val_loss: 1.6849 - val_accuracy: 0.1750
# Epoch 2/50
# 15/15 [==============================] - 35s 2s/step - loss: 1.6893 - accuracy: 0.2250 - val_loss: 1.5906 - val_accuracy: 0.2750
# Epoch 3/50
# 15/15 [==============================] - 35s 2s/step - loss: 1.6256 - accuracy: 0.2583 - val_loss: 1.5767 - val_accuracy: 0.3250
# Epoch 4/50
# 15/15 [==============================] - 37s 2s/step - loss: 1.6079 - accuracy: 0.2750 - val_loss: 1.6232 - val_accuracy: 0.2250
# Epoch 5/50
# 15/15 [==============================] - 37s 2s/step - loss: 1.5847 - accuracy: 0.2083 - val_loss: 1.6262 - val_accuracy: 0.3000
# Epoch 6/50
# 15/15 [==============================] - 37s 2s/step - loss: 1.6387 - accuracy: 0.2250 - val_loss: 1.6212 - val_accuracy: 0.1250
# Epoch 7/50
# ...

# %%
# Accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
from keras import regularizers

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), kernel_regularizer=regularizers.l2(0.001), input_shape=(640, 640, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=15,
      epochs=50,
      validation_data=val_generator,
      validation_steps=5)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 39s 2s/step - loss: 20.0402 - accuracy: 0.2241 - val_loss: 1.6525 - val_accuracy: 0.2000
# Epoch 2/50
# 15/15 [==============================] - 35s 2s/step - loss: 1.8538 - accuracy: 0.2083 - val_loss: 1.6230 - val_accuracy: 0.1750
# Epoch 3/50
# 15/15 [==============================] - 36s 2s/step - loss: 1.6543 - accuracy: 0.1917 - val_loss: 1.6160 - val_accuracy: 0.2000
# Epoch 4/50
# 15/15 [==============================] - 35s 2s/step - loss: 1.5885 - accuracy: 0.3167 - val_loss: 1.5981 - val_accuracy: 0.2000
# Epoch 5/50
# 15/15 [==============================] - 35s 2s/step - loss: 1.6622 - accuracy: 0.2750 - val_loss: 1.6407 - val_accuracy: 0.1750
# Epoch 6/50
# 15/15 [==============================] - 31s 2s/step - loss: 1.6509 - accuracy: 0.2417 - val_loss: 1.6077 - val_accuracy: 0.2000
# Epoch 7/50
# ...

# %%
# Accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), kernel_regularizer=regularizers.l2(0.001), input_shape=(512, 512, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=15,
      epochs=30,
      validation_data=val_generator,
      validation_steps=5)
# Out:
# Epoch 1/30
# 15/15 [==============================] - 27s 2s/step - loss: 5.4860 - accuracy: 0.1583 - val_loss: 1.5981 - val_accuracy: 0.1750
# Epoch 2/30
# 15/15 [==============================] - 26s 2s/step - loss: 1.7127 - accuracy: 0.2500 - val_loss: 1.7968 - val_accuracy: 0.1250
# Epoch 3/30
# 15/15 [==============================] - 25s 2s/step - loss: 1.6599 - accuracy: 0.1750 - val_loss: 1.7073 - val_accuracy: 0.1750
# Epoch 4/30
# 15/15 [==============================] - 26s 2s/step - loss: 1.6234 - accuracy: 0.1583 - val_loss: 1.6055 - val_accuracy: 0.2250
# Epoch 5/30
# 15/15 [==============================] - 26s 2s/step - loss: 1.6103 - accuracy: 0.2250 - val_loss: 1.9662 - val_accuracy: 0.3000
# Epoch 6/30
# 15/15 [==============================] - 25s 2s/step - loss: 1.7546 - accuracy: 0.1917 - val_loss: 1.6112 - val_accuracy: 0.2750
# Epoch 7/30
# ...

# %%
# Accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
